# %%
import os
import gymnasium as gym

from pytorch.config import Config
from pytorch.model import DQN
from pytorch.agent import QAgent
env = gym.make("Taxi-v3") 
config = "pytorch/config_pytorch.yaml"
agent = QAgent(env=env, config=config, model_class=DQN)
agent.compile()
agent.fit()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 11
#       9 agent = QAgent(env=env, config=config, model_class=DQN)
#      10 agent.compile()
# ---> 11 agent.fit()
#
# File ~/taxi_project/rl-taxi/pytorch/agent.py:187, in QAgent.fit(self)
#     183     epsilon = self._get_epsilon(i_episode - self.config.training.warmup_episode)
#     185 for step in count():
#     186     # Select and perform an action
# --> 187     action = self._choose_action(state, epsilon)
#     188     next_state, reward, done, filler, _ = self.env.step(action)
#     190     # Store the transition in memory
#
# File ~/taxi_project/rl-taxi/pytorch/agent.py:92, in QAgent._choose_action(self, state, epsilon)
#      89     action = self.env.action_space.sample()
#      90 else:
#      91     # Exploit
# ---> 92     action = self._get_action_for_state(state)
#      93 return action
#
# File ~/taxi_project/rl-taxi/pytorch/agent.py:82, in QAgent._get_action_for_state(self, state)
#      77 def _get_action_for_state(self, state):
#      78     with torch.no_grad():
#      79         # t.max(1) will return largest column value of each row.
#      80         # second column on max result is index of where max element was
#      81         # found, so we pick action with the larger expected reward.
# ---> 82         predicted = self.model(torch.tensor([state], device=self.device))
#      83         action = predicted.max(1)[1]
#      84     return action.item()
#
# RuntimeError: Could not infer dtype of dict

# %%
agent.play(sleep=0.1, max_steps=20)
