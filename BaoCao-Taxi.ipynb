# %%
import os
import gymnasium as gym

from pytorch.config import Config
from pytorch.model import DQN
from pytorch.agent import QAgent
env = gym.make("Taxi-v3") 
config = "pytorch/config_pytorch.yaml"
agent = QAgent(env=env, config=config, model_class=DQN)
agent.compile()
agent.fit()

# %%
agent.play(sleep=0.1, max_steps=20)
# Out:
# /home/ubuntu/anaconda3/envs/ipl/lib/python3.10/site-packages/gymnasium/envs/toy_text/taxi.py:315: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("Taxi-v3", render_mode="rgb_array")
#   gym.logger.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 agent.play(sleep=0.1, max_steps=20)
#
# File ~/taxi_project/rl-taxi/pytorch/agent.py:368, in QAgent.play(self, verbose, sleep, max_steps)
#     366 action = self._get_action_for_state(state)
#     367 iteration += 1
# --> 368 state, reward, done, info = self.env.step(action)
#     369 display.clear_output(wait=True)
#     370 self.env.render()
#
# ValueError: too many values to unpack (expected 4)
